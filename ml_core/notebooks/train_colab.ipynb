# %%
# ============================================================
# CELL 1: GPU Check + Drive Mount
# Runtime > Change runtime type > T4 GPU (REQUIRED)
# ============================================================
import torch

print(f"PyTorch: {torch.__version__}")
print(f"CUDA: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    vram = torch.cuda.get_device_properties(0).total_memory / 1e9
    print(f"VRAM: {vram:.1f} GB")
    assert vram > 8, "⚠️ Need at least 8GB VRAM"

from google.colab import drive
drive.mount('/content/drive')
# Out:
# PyTorch: 2.10.0+cpu
# CUDA: False
# Mounted at /content/drive

# %%
# Change directory to where your 'raw' folder is
# %cd /content/drive/MyDrive/Skin_triage_data/ml_core/data

print("Zipping the raw data folder. This will take ~15 minutes ONE TIME...")
# Create a zip file named 'raw.zip' containing the 'raw' folder
# !zip -r -q raw.zip raw/

print("✅ Zip file created permanently in your Google Drive!")
# Out:
# /content/drive/MyDrive/Skin_triage_data/ml_core/data
# Zipping the raw data folder. This will take ~15 minutes ONE TIME...
# ✅ Zip file created permanently in your Google Drive!

# %%
# ============================================================
# CELL 2: Install dependencies + set working directory
# ============================================================
# !pip install -q albumentations timm torchmetrics

import sys
import os

# ← UPDATE THIS if your path changes
DRIVE_ROOT = "/content/drive/MyDrive/Skin_triage_data/ml_core"

os.chdir(DRIVE_ROOT)
sys.path.insert(0, DRIVE_ROOT)

print(f"Working directory: {os.getcwd()}")
print(f"Files: {os.listdir('.')}")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 14.3 MB/s eta 0:00:00
# Working directory: /content/drive/MyDrive/Skin_triage_data/ml_core
# Files: ['requirements.txt', 'tests', 'test_pipeline.py', 'logs', 'src', 'notebooks', 'config', 'data', 'checkpoints', 'results']

# %%
# ============================================================
# NEW CELL 2.5: Fast 60-Second Data Transfer (The Zip Method)
# ============================================================
print("Extracting 25k images from Drive to Colab SSD...")

# 1. Create the local folder on the new VM
# !mkdir -p /content/local_data

# 2. Unzip the single file directly to the fast SSD
# !unzip -q /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw.zip -d /content/local_data/

print("✅ Data successfully extracted to local high-speed storage!")
# Out:
# Extracting 25k images from Drive to Colab SSD...
# ✅ Data successfully extracted to local high-speed storage!

# %%
# ============================================================
# CELL 3: Load config + build dataloaders + class weights
# ============================================================
import torch
import logging
logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s')

from src.utils.config import load_config
from src.datasets.dataloader import create_dataloaders_from_config, compute_class_weights

# 1. Load configuration
config = load_config("config/config.yaml")

# 🚨 THE SPEED HACKS (Force the local SSD path) 🚨
config.paths.raw_dir = "/content/local_data/raw"
config.training.num_workers = 2

# 🚨 FORCE GPU DETECTION 🚨
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("\n" + "="*40)
print(f"🔥 HARDWARE CHECK: {device.type.upper()} 🔥")
if device.type == 'cuda':
    print(f"GPU Model: {torch.cuda.get_device_name(0)}")
print("="*40 + "\n")

# 2. Create dataloaders
dataloaders, datasets = create_dataloaders_from_config(config)

train_loader = dataloaders['train']
val_loader   = dataloaders['val']

print(f"✓ Train batches: {len(train_loader)}")

# 3. Compute class weights

# 3. Compute class weights
class_weights = compute_class_weights(
    csv_path=config.paths.train_csv,
    class_to_idx=config.dataset.class_to_idx
)
class_weights = class_weights.to(device)

print("\n✅ Fast Dataloaders Ready!")
# Out:
# ========================================
# 🔥 HARDWARE CHECK: CPU 🔥
# ========================================
# /usr/local/lib/python3.12/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# ✓ Train batches: 555
#
# ✅ Fast Dataloaders Ready!

# %%
import sys
import importlib

# 1. Force reload the trainer module
import src.training.trainer
importlib.reload(src.training.trainer)

# 2. Re-import the Trainer class from the fresh module
from src.training.trainer import Trainer

print("✅ Trainer module successfully reloaded from disk!")
# Out:
# ✅ Trainer module successfully reloaded from disk!

# %%
import importlib
import re

file_path = '/content/drive/MyDrive/Skin_triage_data/ml_core/src/training/trainer.py'

# Read the current file
with open(file_path, 'r') as f:
    code = f.read()

# Replace any lingering 3-variable unpacks with the correct 2-variable unpack
if "for images, labels, _ in pbar:" in code:
    code = re.sub(r'for images, labels, _ in pbar:', r'for images, labels in pbar:', code)

    # Save the file back to Drive
    with open(file_path, 'w') as f:
        f.write(code)
    print("✅ Validation loop patched successfully!")
else:
    print("✅ No more bugs found in the loops!")

# Force Python to use the newly patched file
import src.training.trainer
importlib.reload(src.training.trainer)
from src.training.trainer import Trainer

print("✅ Trainer reloaded and ready for action.")
# Out:
# ✅ No more bugs found in the loops!
# ✅ Trainer reloaded and ready for action.

# %%
# ============================================================
# CELL 4: Train Model 1 — EfficientNet-B0
# Expected time: ~60-90 min on T4
# Expected balanced acc: 75-82%
# ============================================================
MODEL_NAME = "efficientnet_b0"

model = build_model(
    backbone_name=MODEL_NAME,
    num_classes=config.dataset.num_classes,
    dropout=0.3,
    pretrained=True,
    device=device
)

trainer = Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    class_weights=class_weights,
    config=config,
    device=device,
    model_name=MODEL_NAME,
    checkpoint_dir=config.paths.checkpoints_dir,
)

# Phase 1: Head-only warmup (5 epochs)
print("Phase 1: Warming up classification head (5 epochs)...")
model.freeze_backbone()
trainer.num_epochs = 5
trainer.train()

# Phase 2: Full fine-tuning
print("\nPhase 2: Full fine-tuning...")
model.unfreeze_backbone()
trainer.num_epochs = config.training.num_epochs
trainer.early_stopping.counter = 0  # Reset early stopping
history_efficientnet = trainer.train()

print("\n✅ EfficientNet-B0 training complete!")
print(f"   Best Balanced Acc: {trainer.best_val_balanced_acc:.4f}")

# %%
# ============================================================
# CELL 4: RESUME Train Model 1 — EfficientNet-B0 (CPU Mode)
# ============================================================
import torch
from pathlib import Path

# 🚨 THE MAGIC LINES THAT FIX YOUR ERROR 🚨
from src.models.classifier import build_model
from src.training.trainer import Trainer
# =========================================

MODEL_NAME = "efficientnet_b0"

# 1. Build the model architecture
# (pretrained=False because we are going to load your saved weights instead)
model = build_model(
    backbone_name=MODEL_NAME,
    num_classes=config.dataset.num_classes,
    dropout=0.3,
    pretrained=False,
    device=device
)

# 2. Setup the Trainer
trainer = Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    class_weights=class_weights,
    config=config,
    device=device,
    model_name=MODEL_NAME,
    checkpoint_dir=config.paths.checkpoints_dir,
)

# 3. Look for the saved checkpoint in Google Drive
checkpoint_path = Path(config.paths.checkpoints_dir) / f"{MODEL_NAME}_latest.pth"

if checkpoint_path.exists():
    print(f"✅ Found checkpoint: {checkpoint_path}")

    # Load the file from Drive into the CPU (bypassing the PyTorch 2.6 security check)
    checkpoint = torch.load(checkpoint_path, map_location=device, weights_only=False)

    # Restore the model weights and optimizer learning rate
    model.load_state_dict(checkpoint['model_state_dict'])
    trainer.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    trainer.best_val_balanced_acc = checkpoint.get('val_balanced_acc', 0.0)

    # Calculate where we left off
    epochs_completed = checkpoint.get('epoch', 0) + 1
    print(f"🚀 Successfully loaded weights! Resuming after {epochs_completed} epochs...")

    # 4. Resume Phase 2 (Full fine-tuning)
    # 4. Resume Phase 2 (Full fine-tuning)
    print(f"\nPhase 2: Resuming full fine-tuning on {device}...")
    model.unfreeze_backbone()

    epochs_total = config.training.num_epochs
    epochs_remaining = epochs_total - epochs_completed

    if epochs_remaining > 0:
        trainer.num_epochs = epochs_remaining
        trainer.early_stopping.counter = 0  # Reset early stopping
        history_efficientnet = trainer.train()
        print("\n✅ Resumed training complete!")
        print(f"   Best Balanced Acc: {trainer.best_val_balanced_acc:.4f}")
    else:
        print("\n✅ Model has already completed all 30 epochs!")

else:
    print(f"❌ ERROR: No checkpoint found at {checkpoint_path}!")
    print("Check your Drive connection. Did you mount Google Drive?")
# Out:
# /content/drive/MyDrive/Skin_triage_data/ml_core/src/training/trainer.py:121: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = GradScaler(enabled=self.use_amp)
# ✅ Found checkpoint: checkpoints/efficientnet_b0_latest.pth
# 🚀 Successfully loaded weights! Resuming after 5 epochs...
#
# Phase 2: Resuming full fine-tuning on cpu...
# Epoch 1 [Train]:   0%|          | 0/555 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:1118: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# /content/drive/MyDrive/Skin_triage_data/ml_core/src/training/trainer.py:171: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.use_amp):
# Epoch 1 [Train]:  46%|████▌     | 255/555 [1:00:59<58:51, 11.77s/it, loss=0.2017, acc=86.9%]  ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0060467: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0060467.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0071143: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0071143.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0059467: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0059467.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0063583: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0063583.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0000157: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0000157.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0063755: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0063755.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0055792: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0055792.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0054607: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0054607.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0062119: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0062119.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0057059: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0057059.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0064679: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0064679.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0000549: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0000549.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0027034: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0027034.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0030284: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0030284.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0060612: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0060612.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0063180: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0063180.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0033823: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0033823.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0000103_downsampled: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0000103_downsampled.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0009870: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0009870.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0029375: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0029375.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0071869: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0071869.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0015045_downsampled: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0015045_downsampled.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0031659: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0031659.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0012518_downsampled: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0012518_downsampled.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0029702: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0029702.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0033815: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0033815.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0069309: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0069309.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0059370: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0059370.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0053739: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0053739.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0030973: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0030973.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0059143: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0059143.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0025553: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0025553.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0068858: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0068858.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0059855: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0059855.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0033562: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0033562.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0027353: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0027353.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0012271_downsampled: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0012271_downsampled.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0029289: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0029289.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0070233: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0070233.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0010595: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0010595.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0030809: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0030809.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0029390: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0029390.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0062738: Failed to read image (corrupted?): /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0062738.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0024999: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0024999.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0014609_downsampled: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0014609_downsampled.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0030068: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0030068.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0030025: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0030025.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0013813_downsampled: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0013813_downsampled.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0070266: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0070266.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0014651_downsampled: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0014651_downsampled.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0058050: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0058050.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0056108: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0056108.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0029858: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0029858.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0062402: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0062402.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0068457: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0068457.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0026570: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0026570.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0054649: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0054649.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0062313: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0062313.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0027009: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0027009.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0069259: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0069259.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0070304: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0070304.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0053936: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0053936.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0028379: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0028379.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0029445: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0029445.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0026512: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0026512.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0029018: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0029018.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0056330: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0056330.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0064915: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0064915.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0072450: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0072450.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0060337: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0060337.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0072943: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0072943.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0062271: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0062271.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0029176: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0029176.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0033519: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0033519.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0027802: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0027802.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0026467: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0026467.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0067043: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0067043.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0070663: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0070663.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0069402: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0069402.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0072496: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0072496.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0054315: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0054315.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0059565: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0059565.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0004985_downsampled: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0004985_downsampled.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0024512: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0024512.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0068792: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0068792.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0059047: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0059047.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0027055: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0027055.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0030115: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0030115.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0067652: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0067652.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0067340: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0067340.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0054226: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0054226.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0025420: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0025420.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0025729: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0025729.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0032978: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0032978.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0069843: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0069843.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0000477: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0000477.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0056260: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0056260.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0063179: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0063179.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0069907: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0069907.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0014185_downsampled: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0014185_downsampled.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0070132: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0070132.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0030364: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0030364.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0029387: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0029387.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0063274: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0063274.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0066480: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0066480.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0062839: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0062839.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0069929: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0069929.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0066318: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0066318.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0063809: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0063809.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0061883: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0061883.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0070253: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0070253.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0064778: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0064778.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0055407: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0055407.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0067621: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0067621.jpg
# Epoch 1 [Train]:  46%|████▌     | 256/555 [1:01:15<1:04:23, 12.92s/it, loss=1.1516, acc=86.8%]ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0063748: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0063748.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0027515: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0027515.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0026408: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0026408.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0032955: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0032955.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0070472: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0070472.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0032170: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0032170.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0060333: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0060333.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0063697: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0063697.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0064967: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0064967.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0059583: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0059583.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0026543: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0026543.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0073025: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0073025.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0061049: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0061049.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0026099: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0026099.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0026649: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0026649.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0025504: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0025504.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0069142: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0069142.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0062225: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0062225.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0064831: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0064831.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0013688_downsampled: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0013688_downsampled.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0010081: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0010081.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0028708: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0028708.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0033214: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0033214.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0026301: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0026301.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0030334: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0030334.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0034285: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0034285.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0026754: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0026754.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0060706: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0060706.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0030816: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0030816.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0065920: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0065920.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0014162_downsampled: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0014162_downsampled.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0014197_downsampled: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0014197_downsampled.jpg
# Epoch 1 [Train]:  46%|████▋     | 257/555 [1:01:21<53:47, 10.83s/it, loss=1.2671, acc=86.7%]  ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0071479: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0071479.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0026938: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0026938.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0024760: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0024760.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0056333: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0056333.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0059441: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0059441.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0072633: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0072633.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0030277: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0030277.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0026619: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0026619.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0007475_downsampled: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0007475_downsampled.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0063462: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0063462.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0059028: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0059028.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0055105: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0055105.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0030993: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0030993.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0000299: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0000299.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0065864: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0065864.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0071362: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0071362.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0032064: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0032064.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0016023_downsampled: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0016023_downsampled.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0067155: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0067155.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0025222: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0025222.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0053584: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0053584.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0071022: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0071022.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0072343: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0072343.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0027224: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0027224.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0032702: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0032702.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0032542: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0032542.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0027108: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0027108.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0063458: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0063458.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0028937: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0028937.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0033640: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0033640.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0073227: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0073227.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0028114: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0028114.jpg
# Epoch 1 [Train]:  46%|████▋     | 258/555 [1:01:26<45:59,  9.29s/it, loss=5.5524, acc=86.6%]ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0058772: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0058772.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0064544: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0064544.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0068091: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0068091.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0060902: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0060902.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0027772: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0027772.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0060310: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0060310.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0061325: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0061325.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0067495: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0067495.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0027660: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0027660.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0033267: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0033267.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0034290: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0034290.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0059657: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0059657.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0034077: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0034077.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0025877: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0025877.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0059595: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0059595.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0062112: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0062112.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0012735_downsampled: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0012735_downsampled.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0014229_downsampled: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0014229_downsampled.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0054497: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0054497.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0059930: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0059930.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0028364: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0028364.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0071944: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0071944.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0029573: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0029573.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0027546: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0027546.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0065221: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0065221.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0067109: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0067109.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0067679: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0067679.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0068540: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0068540.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0029473: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0029473.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0010092: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0010092.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0034148: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0034148.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0025763: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0025763.jpg
# Epoch 1 [Train]:  47%|████▋     | 259/555 [1:01:32<40:55,  8.30s/it, loss=2.1430, acc=86.5%]ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0058027: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0058027.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0070900: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0070900.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0030342: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0030342.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0061258: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0061258.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0034062: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0034062.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0030944: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0030944.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0067265: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0067265.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0033555: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0033555.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0015403_downsampled: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0015403_downsampled.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0067592: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0067592.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0072410: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0072410.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0057817: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0057817.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0030023: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0030023.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0070201: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0070201.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0032474: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0032474.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0029932: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0029932.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0025277: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0025277.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0030165: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0030165.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0032371: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0032371.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0060311: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0060311.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0010364: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0010364.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0070575: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0070575.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0067456: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0067456.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0031705: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0031705.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0029776: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0029776.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0025011: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0025011.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0054693: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0054693.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0032669: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0032669.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0064292: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0064292.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0015224_downsampled: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0015224_downsampled.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0027868: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0027868.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0065826: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0065826.jpg
# Epoch 1 [Train]:  47%|████▋     | 260/555 [1:01:37<35:54,  7.30s/it, loss=2.3173, acc=86.4%]ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0066132: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0066132.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0055443: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0055443.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0030054: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0030054.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0014633_downsampled: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0014633_downsampled.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0067784: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0067784.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0014044_downsampled: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0014044_downsampled.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0009932: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0009932.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0065426: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0065426.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0063485: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0063485.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0030190: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0030190.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0000384_downsampled: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0000384_downsampled.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0061506: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0061506.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0072412: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0072412.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0066354: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0066354.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0060930: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0060930.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0057025: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0057025.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0070933: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0070933.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0062128: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0062128.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0057215: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0057215.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0065640: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0065640.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0025432: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0025432.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0061918: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0061918.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0025841: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0025841.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0065784: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0065784.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0025932: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0025932.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0000541: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0000541.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0030698: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0030698.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0058944: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0058944.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0056557: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0056557.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0031053: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0031053.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0065790: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/ISIC_2019/ISIC_2019_Training_Input/ISIC_0065790.jpg
# ERROR:src.datasets.skin_lesion_dataset:Error loading image ISIC_0030775: Image not found: /content/drive/MyDrive/Skin_triage_data/ml_core/data/raw/HAM_10000/images/ISIC_0030775.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2821077388.py in <cell line: 0>()
#      63         trainer.num_epochs = epochs_remaining
#      64         trainer.early_stopping.counter = 0  # Reset early stopping
# ---> 65         history_efficientnet = trainer.train()
#      66         print("\n✅ Resumed training complete!")
#      67         print(f"   Best Balanced Acc: {trainer.best_val_balanced_acc:.4f}")
#
# /content/drive/MyDrive/Skin_triage_data/ml_core/src/training/trainer.py in train(self)
#     318
#     319             # Train
# --> 320             train_loss, train_acc = self._train_one_epoch(epoch)
#     321
#     322             # Validate
#
# /content/drive/MyDrive/Skin_triage_data/ml_core/src/training/trainer.py in _train_one_epoch(self, epoch)
#     174
#     175             # Backward pass
# --> 176             self.scaler.scale(loss).backward()
#     177
#     178             # Gradient clipping (prevents exploding gradients)
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     628                 inputs=inputs,
#     629             )
# --> 630         torch.autograd.backward(
#     631             self, gradient, retain_graph, create_graph, inputs=inputs
#     632         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     362     # some Python versions print out the first line of a multi-line function
#     363     # calls in the traceback and some print out the last line
# --> 364     _engine_run_backward(
#     365         tensors,
#     366         grad_tensors_,
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     863         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     864     try:
# --> 865         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     866             t_outputs, *args, **kwargs
#     867         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
# ============================================================
# CELL 5: Train Model 2 — ResNet50
# Expected time: ~90-120 min on T4
# Expected balanced acc: 73-80%
# ============================================================
MODEL_NAME = "resnet50"

model = build_model(
    backbone_name=MODEL_NAME,
    num_classes=config.dataset.num_classes,
    dropout=0.3,
    pretrained=True,
    device=device
)

trainer = Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    class_weights=class_weights,
    config=config,
    device=device,
    model_name=MODEL_NAME,
    checkpoint_dir=config.paths.checkpoints_dir,
)

model.freeze_backbone()
trainer.num_epochs = 5
trainer.train()

model.unfreeze_backbone()
trainer.num_epochs = config.training.num_epochs
trainer.early_stopping.counter = 0
history_resnet = trainer.train()

print("\n✅ ResNet50 training complete!")
print(f"   Best Balanced Acc: {trainer.best_val_balanced_acc:.4f}")

# %%
# ============================================================
# CELL 6: Train Model 3 — ConvNeXt-Tiny (SOTA candidate)
# Expected time: ~90-120 min on T4
# Expected balanced acc: 78-85% (likely WINNER)
# ============================================================
MODEL_NAME = "convnext_tiny"

model = build_model(
    backbone_name=MODEL_NAME,
    num_classes=config.dataset.num_classes,
    dropout=0.3,
    pretrained=True,
    device=device
)

trainer = Trainer(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    class_weights=class_weights,
    config=config,
    device=device,
    model_name=MODEL_NAME,
    checkpoint_dir=config.paths.checkpoints_dir,
)

model.freeze_backbone()
trainer.num_epochs = 5
trainer.train()

model.unfreeze_backbone()
trainer.num_epochs = config.training.num_epochs
trainer.early_stopping.counter = 0
history_convnext = trainer.train()

print("\n✅ ConvNeXt-Tiny training complete!")
print(f"   Best Balanced Acc: {trainer.best_val_balanced_acc:.4f}")

# %%
# ============================================================
# CELL 7: Evaluate all 3 models on HELD-OUT test set
# Only run this ONCE — after all training is done.
# ============================================================
import numpy as np
import pandas as pd

metrics_calc = MetricsCalculator(
    class_names=config.dataset.class_names,
    results_dir=config.paths.results_dir
)

results = []

for model_name in ['efficientnet_b0', 'resnet50', 'convnext_tiny']:
    checkpoint_path = f"{config.paths.checkpoints_dir}/{model_name}_best.pth"

    model = build_model(
        backbone_name=model_name,
        num_classes=config.dataset.num_classes,
        dropout=0.3,
        pretrained=False,  # Will load from checkpoint
        checkpoint_path=checkpoint_path,
        device=device
    )
    model.eval()

    all_preds, all_labels, all_probs = [], [], []

    with torch.no_grad():
        for images, labels, _ in test_loader:
            images = images.to(device)
            logits = model(images)
            probs = torch.softmax(logits, dim=1)
            preds = probs.argmax(dim=1)
            all_preds.append(preds.cpu().numpy())
            all_labels.append(labels.cpu().numpy())
            all_probs.append(probs.cpu().numpy())

    all_preds = np.concatenate(all_preds)
    all_labels = np.concatenate(all_labels)
    all_probs = np.concatenate(all_probs)

    # Compute metrics
    metrics = metrics_calc.compute(all_preds, all_labels, all_probs, split='test')
    metrics_calc.plot_confusion_matrix(all_preds, all_labels, model_name, 'test')
    metrics_calc.save_metrics_csv(metrics, model_name, 'test')

    results.append({
        'model': model_name,
        'balanced_acc': metrics['balanced_accuracy'],
        'mel_sensitivity': metrics['mel_sensitivity'],
        'mel_auc': metrics['auc_roc_melanoma'],
        'f1_macro': metrics['f1_macro'],
        'auc_macro': metrics['auc_roc_macro'],
    })
    print(f"\n[{model_name}] Balanced Acc: {metrics['balanced_accuracy']:.4f} | "
          f"Mel Sensitivity: {metrics['mel_sensitivity']:.4f}")

# Final comparison table
print("\n" + "="*70)
print("MODEL COMPARISON — FINAL TEST SET RESULTS")
print("="*70)
df = pd.DataFrame(results).set_index('model')
print(df.to_string())

winner = df['balanced_acc'].idxmax()
print(f"\n🏆 BEST MODEL: {winner}")
print(f"   → This model proceeds to Phase 3 (Uncertainty + OOD)")
